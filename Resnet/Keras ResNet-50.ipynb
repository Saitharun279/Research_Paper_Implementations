# %%
from tensorflow.python.keras.applications import ResNet50
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Flatten, GlobalAveragePooling2D

num_classes = 2
resnet_weights_path = '../input/resnet50/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5'

my_new_model = Sequential()
my_new_model.add(ResNet50(include_top=False, pooling='avg', weights=resnet_weights_path))
my_new_model.add(Dense(2, activation='softmax'))

# Say not to train first layer (ResNet) model. It is already trained
my_new_model.layers[0].trainable = False

# %%
my_new_model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.python.keras.applications.resnet50 import preprocess_input
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator

image_size = 224
data_generator = ImageDataGenerator()


train_generator = data_generator.flow_from_directory(
        '../input/covid19/covid19/train',
        target_size=(image_size, image_size),
        batch_size=24,
        class_mode='categorical')
# Out:
# Found 425 images belonging to 2 classes.

# %%
validation_generator = data_generator.flow_from_directory(
        '../input/covid19/covid19/val',
        target_size=(image_size, image_size),
        class_mode='categorical')
# Out:
# Found 118 images belonging to 2 classes.

# %%
test_generator = data_generator.flow_from_directory(
    '../input/covid19/covid19/test',
    target_size=(image_size,image_size),
    class_mode='categorical'
)
# Out:
# Found 203 images belonging to 2 classes.

# %%
my_new_model.fit_generator(
        train_generator,
        steps_per_epoch=3,
        validation_data=validation_generator,
        validation_steps=1,
        epochs=25)
# Out:
# Epoch 1/25
# 3/3 [==============================] - 1s 300ms/step - loss: 0.2754 - acc: 0.9167 - val_loss: 1.0479 - val_acc: 0.5312
# Epoch 2/25
# 3/3 [==============================] - 1s 212ms/step - loss: 0.3175 - acc: 0.8472 - val_loss: 0.9435 - val_acc: 0.5625
# Epoch 3/25
# 3/3 [==============================] - 1s 204ms/step - loss: 0.3188 - acc: 0.8750 - val_loss: 1.3655 - val_acc: 0.5625
# Epoch 4/25
# 3/3 [==============================] - 1s 214ms/step - loss: 0.2891 - acc: 0.8730 - val_loss: 0.9083 - val_acc: 0.5000
# Epoch 5/25
# 3/3 [==============================] - 1s 203ms/step - loss: 0.3214 - acc: 0.8750 - val_loss: 0.8778 - val_acc: 0.5000
# Epoch 6/25
# 3/3 [==============================] - 1s 217ms/step - loss: 0.2410 - acc: 0.9167 - val_loss: 0.8666 - val_acc: 0.4688
# Epoch 7/25
# 3/3 [==============================] - 1s 235ms/step - loss: 0.2862 - acc: 0.9167 - val_loss: 0.8211 - val_acc: 0.4688
# Epoch 8/25
# ...

# %%
my_new_model.predict_generator(test_generator)
# Out:
# array([[0.82312787, 0.1768721 ],
#        [0.03672612, 0.9632739 ],
#        [0.61103636, 0.3889636 ],
#        [0.29955447, 0.70044553],
#        [0.46542537, 0.5345746 ],
#        [0.4653884 , 0.53461164],
#        [0.34356216, 0.6564379 ],
#        [0.17175454, 0.8282454 ],
#        [0.00418052, 0.99581945],
#        [0.2145452 , 0.7854548 ],
#        [0.01248667, 0.98751336],
#        [0.40940073, 0.59059924],
#        [0.15213555, 0.84786445],
#        [0.01050093, 0.9894991 ],
#        [0.34717256, 0.65282744],
#        [0.03017493, 0.9698251 ],
#        [0.22708859, 0.7729114 ],
#        [0.1305375 , 0.8694625 ],
#        [0.6880803 , 0.3119197 ],
#        [0.11567611, 0.8843239 ],
#        [0.6269838 , 0.37301615],
#        [0.44690388, 0.5530961 ],
#        [0.3471102 , 0.6528898 ],
#        [0.22658741, 0.7734126 ],
#        [0.4325983 , 0.5674017 ],
#        [0.1242204 , 0.8757796 ],
#        [0.03753429, 0.96246576],
#        [0.26867893, 0.73132104],
# ...

# %%
my_new_model.evaluate_generator(test_generator)
# Out:
# [0.8748944058206868, 0.5615763540925651]
